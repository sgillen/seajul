# %%
include("seajul.jl")

using Distributed
using PyCall
using .SJ
using Plots
using Statistics

addprocs(16)

gym = pyimport("gym")
mj = pyimport("mujoco_py")

env = gym.make("HalfCheetah-v2")
# Out:
# running build_ext
# WARNING: Overriding pythran description with argspec information for: numpy.concatenate
# WARNING: Overriding pythran description with argspec information for: numpy.empty_like
# PyObject <TimeLimit<HalfCheetahEnv<HalfCheetah-v2>>>

# %%
function do_rollout(env::PyObject, W, μ, σ ; render=false)
    x = env.reset()
    done = false
    reward = 0.0
    
    X = zeros(env.observation_space.shape[1])
    U = zeros(env.action_space.shape[1])
    R = zeros(1)
    
    while !done
        
        for o in x
            push!(X,o)
        end

        
        u = clamp(W*((x-μ)./σ), env.action_space.low, env.action_space.high)
        x, r, done, _ = env.step(u)
        reward += r
        
        
        if render
            env.render()
            sleep(.02)
        end
            
        
        for a in u
            push!(U,a)
        end
        
        push!(R,r)
        
    end
    
    X = reshape(X,(env.observation_space.shape[1],:))
    U = reshape(U,(env.action_space.shape[1]),:)
     
    return X,U,R
end
# Out:
# do_rollout (generic function with 1 method)

# %%
W = randn(env.action_space.shape[1], env.observation_space.shape[1])
X,U,R = do_rollout(env, W, zeros(size(W)[2]), ones(size(W)[2]))
print(size(X))
println(findmax(X,dims=2))
# Out:
# (17, 1001)([0.0386558719166475; 0.30128955943392205; 0.31968046044316856; 0.36298616348394025; 0.2822006896846888; 0.6294232972217441; 0.5341467584329516; 0.5095188462472416; 3.502635363780526; 1.6513050504517994; 4.478670557675935; 9.464395742500535; 12.426877943730574; 15.889501689633049; 12.517350611364982; 12.493847554051584; 11.384267218194456], CartesianIndex{2}[CartesianIndex(1, 441); CartesianIndex(2, 359); CartesianIndex(3, 570); CartesianIndex(4, 177); CartesianIndex(5, 514); CartesianIndex(6, 354); CartesianIndex(7, 354); CartesianIndex(8, 354); CartesianIndex(9, 349); CartesianIndex(10, 439); CartesianIndex(11, 469); CartesianIndex(12, 488); CartesianIndex(13, 913); CartesianIndex(14, 354); CartesianIndex(15, 548); CartesianIndex(16, 676); CartesianIndex(17, 676)])

# %%
@everywhere include("seajul.jl")
 
W = zeros(env.action_space.shape[1], env.observation_space.shape[1])
σ = vec(std(X,dims=2))
@time r_log, W, μ, Σ = SJ.ars!(env, W,μ, σ, num_epochs=10, N=32,b=4,α=.02)

println(W)
plot(r_log)
# Out:
#       From worker 3:	WARNING: replacing module SJ.
#       From worker 12:	WARNING: replacing module SJ.
#       From worker 4:	WARNING: replacing module SJ.
#       From worker 7:	WARNING: replacing module SJ.
#       From worker 5:	WARNING: replacing module SJ.
#       From worker 10:	WARNING: replacing module SJ.
#       From worker 13:	WARNING: replacing module SJ.
#       From worker 6:	WARNING: replacing module SJ.
#       From worker 11:	WARNING: replacing module SJ.
#       From worker 9:	WARNING: replacing module SJ.
#       From worker 16:	WARNING: replacing module SJ.
#       From worker 17:	WARNING: replacing module SJ.
