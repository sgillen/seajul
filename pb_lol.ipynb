# %%
import numpy as np

r = np.load("text.npz")
# Out:
# array([[[-9.33728297e-05,  4.95660934e-04,  2.19594757e-03, ...,
#          -1.05858751e-04,  2.13772734e-03,  1.51134806e-03],
#         [ 7.78555113e-06, -6.15838566e-04,  2.51550972e-03, ...,
#           2.02108102e-04,  9.59194324e-04,  1.61014323e-03],
#         [-2.51044286e-04, -1.54800073e-04, -6.21153566e-04, ...,
#           1.63196062e-04, -2.77325191e-04, -3.50657618e-04],
#         [-1.51805853e-05,  1.12581911e-04,  2.02852883e-03, ...,
#           3.61536717e-04,  2.11921846e-03,  7.42683420e-04],
#         [ 1.99883827e-04,  2.49674253e-04,  2.37043551e-03, ...,
#           5.88078634e-04,  1.52496574e-03,  1.56309933e-03],
#         [-5.68809401e-06,  7.40283067e-05, -7.94462918e-04, ...,
#           2.22374743e-04, -3.43581109e-04,  4.56641807e-04]],
#
#        [[-2.87972827e-04,  1.57723480e-04,  2.31112144e-03, ...,
#          -6.41969382e-06,  2.18995474e-03,  2.36667134e-03],
#         [-5.56275365e-04, -2.38963999e-04,  2.42202613e-03, ...,
# ...
